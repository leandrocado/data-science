# %%
#!unzip ./drive/'My Drive'/dataset/leapGestRecog.zip

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
import torchvision
import numpy as np
from torchvision import datasets, transforms, models
from torch.utils.data.sampler import SubsetRandomSampler
from datetime import datetime

# %%
# Parameters
BATCH_SIZE = 64
RESIZE = 256
EPOCHS = 10
MODEL = models.googlenet
OUR_TOPOLOGY = nn.Sequential(nn.Linear(1024, 512),
                                 nn.ReLU(),
                                 nn.Dropout(0.2),
                                 nn.Linear(512, 10),
                                 nn.LogSoftmax(dim=1))
OPTIMIZER = optim.Adam
OPTIMIZER_PARAMETERS = {"lr": 0.003}

# %%
transform = transforms.Compose([
    transforms.Resize(RESIZE),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

alldataset = torchvision.datasets.ImageFolder(root='./leapGestRecog/00', transform=transform)

for i in range(1, 10):
    folder = torchvision.datasets.ImageFolder(root='./leapGestRecog/0{}'.format(i), transform=transform)
    alldataset = torch.utils.data.ConcatDataset([alldataset, folder])


def split_train_test(indices, seed=42):
    np.random.seed(seed)
    np.random.shuffle(indices)
    train_idx, test_idx = indices[split:], indices[:split]
    train_sampler = SubsetRandomSampler(train_idx)
    test_sampler = SubsetRandomSampler(test_idx)
    trainloader = torch.utils.data.DataLoader(
        alldataset, batch_size=BATCH_SIZE, sampler=train_sampler,
        num_workers=12
    )
    testloader = torch.utils.data.DataLoader(
        alldataset, batch_size=BATCH_SIZE, sampler=test_sampler,
    )
    return train_idx, trainloader, test_idx, testloader

num_train = len(alldataset)
indices = list(range(num_train))
split = int(np.floor(0.1 * num_train))

train_idx, trainloader, test_idx, testloader = split_train_test(indices)
_, trainloader, _, validloader = split_train_test(train_idx)

classes = ('01_palm', '02_l', '03_fist', '04_fist_moved',
           '05_thumb', '06_index', '07_ok', '08_palm_moved', '09_c', '10_down')

# %%
print(len(trainloader), len(validloader), len(testloader))
# Out:
# 250 32 32

# %%
import matplotlib.pyplot as plt
import numpy as np

# functions to show an image


def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
dataiter = iter(trainloader)
images, labels = dataiter.next()

# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(BATCH_SIZE)))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 10_down 08_palm_moved 08_palm_moved 07_ok 10_down 06_index 03_fist 05_thumb 07_ok 08_palm_moved 05_thumb 06_index 03_fist 05_thumb 05_thumb  09_c 06_index 07_ok 01_palm 03_fist 04_fist_moved 08_palm_moved 06_index  09_c  02_l 07_ok 05_thumb 05_thumb 04_fist_moved 08_palm_moved 10_down 07_ok 10_down 08_palm_moved 08_palm_moved 05_thumb 01_palm 05_thumb 10_down 01_palm 01_palm 07_ok 10_down 10_down 07_ok 01_palm 07_ok  02_l 10_down 10_down 07_ok 04_fist_moved 03_fist 04_fist_moved 10_down  02_l  09_c  02_l 06_index 01_palm  02_l 03_fist 10_down 04_fist_moved

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
model = MODEL(pretrained=True)
model
# Out:
# GoogLeNet(
#   (conv1): BasicConv2d(
#     (conv): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool1): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (conv2): BasicConv2d(
#     (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): BasicConv2d(
#     (conv): Conv2d(64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (inception3a): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(192, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception3b): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (maxpool3): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (inception4a): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(480, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(480, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(208, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(480, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(16, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(480, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4b): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(512, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(112, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(24, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4c): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(24, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4d): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(512, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(112, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(144, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(288, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4e): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(528, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(528, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(528, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(528, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (maxpool4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (inception5a): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(832, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception5b): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(832, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(48, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (dropout): Dropout(p=0.2, inplace=False)
#   (fc): Linear(in_features=1024, out_features=1000, bias=True)
# )

# %%
# Freeze parameters so we don't backprop through them
for param in model.parameters():
    param.requires_grad = False
    
model.fc = OUR_TOPOLOGY
criterion = nn.NLLLoss()
optimizer = OPTIMIZER(model.parameters(), **OPTIMIZER_PARAMETERS)
model.to(device)
# Out:
# GoogLeNet(
#   (conv1): BasicConv2d(
#     (conv): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool1): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (conv2): BasicConv2d(
#     (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): BasicConv2d(
#     (conv): Conv2d(64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (inception3a): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(192, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception3b): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (maxpool3): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (inception4a): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(480, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(480, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(208, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(480, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(16, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(480, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4b): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(512, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(112, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(24, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4c): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(24, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4d): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(512, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(112, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(144, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(288, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4e): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(528, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(528, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(528, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(528, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (maxpool4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (inception5a): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(832, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception5b): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(832, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(48, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (dropout): Dropout(p=0.2, inplace=False)
#   (fc): Sequential(
#     (0): Linear(in_features=1024, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=512, out_features=10, bias=True)
#     (4): LogSoftmax()
#   )
# )

# %%
epochs = EPOCHS
steps = 0
running_loss = 0
print_every = 10
train_losses, test_losses = [], []

t1 = datetime.now()
for epoch in range(epochs):
    _, trainloader, _, validloader = split_train_test(train_idx)
    for inputs, labels in trainloader:
        steps += 1
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        logps = model.forward(inputs)
        loss = criterion(logps, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        
        if steps % print_every == 0:
            test_loss = 0
            accuracy = 0
            model.eval()
            with torch.no_grad():
                for inputs, labels in validloader:
                    inputs, labels = inputs.to(device), labels.to(device)
                    logps = model.forward(inputs)
                    batch_loss = criterion(logps, labels)
                    test_loss += batch_loss.item()
                    
                    ps = torch.exp(logps)
                    top_p, top_class = ps.topk(1, dim=1)
                    equals = top_class == labels.view(*top_class.shape)
                    accuracy += torch.mean(equals.type(torch.FloatTensor)).item()

            train_losses.append(running_loss/len(trainloader))
            test_losses.append(test_loss/len(validloader))                    
            print(f"Epoch {epoch+1}/{epochs}.. "
                  f"Train loss: {running_loss/print_every:.3f}.. "
                  f"Test loss: {test_loss/len(validloader):.3f}.. "
                  f"Test accuracy: {accuracy/len(validloader):.3f}")
            running_loss = 0
            model.train()
t2 = datetime.now()
# Out:
# Epoch 1/10.. Train loss: 2.168.. Test loss: 1.784.. Test accuracy: 0.349
# Epoch 1/10.. Train loss: 1.233.. Test loss: 1.225.. Test accuracy: 0.627
# Epoch 1/10.. Train loss: 0.687.. Test loss: 1.015.. Test accuracy: 0.642
# Epoch 1/10.. Train loss: 0.491.. Test loss: 0.580.. Test accuracy: 0.825
# Epoch 1/10.. Train loss: 0.397.. Test loss: 0.472.. Test accuracy: 0.869
# Epoch 1/10.. Train loss: 0.274.. Test loss: 0.338.. Test accuracy: 0.886
# Epoch 1/10.. Train loss: 0.288.. Test loss: 0.184.. Test accuracy: 0.941
# Epoch 1/10.. Train loss: 0.221.. Test loss: 0.128.. Test accuracy: 0.968
# Epoch 1/10.. Train loss: 0.180.. Test loss: 0.102.. Test accuracy: 0.975
# Epoch 1/10.. Train loss: 0.154.. Test loss: 0.101.. Test accuracy: 0.974
# Epoch 1/10.. Train loss: 0.156.. Test loss: 0.068.. Test accuracy: 0.984
# Epoch 1/10.. Train loss: 0.130.. Test loss: 0.066.. Test accuracy: 0.986
# Epoch 1/10.. Train loss: 0.189.. Test loss: 0.066.. Test accuracy: 0.982
# Epoch 1/10.. Train loss: 0.137.. Test loss: 0.066.. Test accuracy: 0.982
# Epoch 1/10.. Train loss: 0.104.. Test loss: 0.049.. Test accuracy: 0.987
# Epoch 1/10.. Train loss: 0.094.. Test loss: 0.035.. Test accuracy: 0.990
# Epoch 1/10.. Train loss: 0.062.. Test loss: 0.033.. Test accuracy: 0.990
# Epoch 1/10.. Train loss: 0.123.. Test loss: 0.036.. Test accuracy: 0.992
# Epoch 1/10.. Train loss: 0.060.. Test loss: 0.023.. Test accuracy: 0.994
# Epoch 1/10.. Train loss: 0.076.. Test loss: 0.037.. Test accuracy: 0.989
# Epoch 1/10.. Train loss: 0.071.. Test loss: 0.022.. Test accuracy: 0.995
# Epoch 1/10.. Train loss: 0.102.. Test loss: 0.027.. Test accuracy: 0.994
# Epoch 1/10.. Train loss: 0.072.. Test loss: 0.043.. Test accuracy: 0.990
# Epoch 1/10.. Train loss: 0.107.. Test loss: 0.022.. Test accuracy: 0.996
# Epoch 1/10.. Train loss: 0.074.. Test loss: 0.032.. Test accuracy: 0.994
# Epoch 2/10.. Train loss: 0.103.. Test loss: 0.042.. Test accuracy: 0.989
# Epoch 2/10.. Train loss: 0.073.. Test loss: 0.048.. Test accuracy: 0.984
# Epoch 2/10.. Train loss: 0.091.. Test loss: 0.020.. Test accuracy: 0.993
# Epoch 2/10.. Train loss: 0.046.. Test loss: 0.017.. Test accuracy: 0.996
# Epoch 2/10.. Train loss: 0.076.. Test loss: 0.017.. Test accuracy: 0.996
# Epoch 2/10.. Train loss: 0.062.. Test loss: 0.055.. Test accuracy: 0.986
# Epoch 2/10.. Train loss: 0.082.. Test loss: 0.014.. Test accuracy: 0.997
# Epoch 2/10.. Train loss: 0.055.. Test loss: 0.037.. Test accuracy: 0.989
# Epoch 2/10.. Train loss: 0.050.. Test loss: 0.029.. Test accuracy: 0.991
# Epoch 2/10.. Train loss: 0.066.. Test loss: 0.022.. Test accuracy: 0.994
# Epoch 2/10.. Train loss: 0.037.. Test loss: 0.020.. Test accuracy: 0.994
# Epoch 2/10.. Train loss: 0.047.. Test loss: 0.029.. Test accuracy: 0.991
# Epoch 2/10.. Train loss: 0.053.. Test loss: 0.043.. Test accuracy: 0.986
# Epoch 2/10.. Train loss: 0.127.. Test loss: 0.141.. Test accuracy: 0.951
# Epoch 2/10.. Train loss: 0.099.. Test loss: 0.024.. Test accuracy: 0.993
# Epoch 2/10.. Train loss: 0.079.. Test loss: 0.019.. Test accuracy: 0.994
# Epoch 2/10.. Train loss: 0.047.. Test loss: 0.013.. Test accuracy: 0.995
# Epoch 2/10.. Train loss: 0.049.. Test loss: 0.012.. Test accuracy: 0.996
# Epoch 2/10.. Train loss: 0.051.. Test loss: 0.014.. Test accuracy: 0.997
# Epoch 2/10.. Train loss: 0.053.. Test loss: 0.023.. Test accuracy: 0.992
# Epoch 2/10.. Train loss: 0.039.. Test loss: 0.018.. Test accuracy: 0.995
# Epoch 2/10.. Train loss: 0.035.. Test loss: 0.020.. Test accuracy: 0.994
# Epoch 2/10.. Train loss: 0.051.. Test loss: 0.025.. Test accuracy: 0.995
# Epoch 2/10.. Train loss: 0.088.. Test loss: 0.019.. Test accuracy: 0.995
# Epoch 2/10.. Train loss: 0.069.. Test loss: 0.024.. Test accuracy: 0.994
# Epoch 3/10.. Train loss: 0.070.. Test loss: 0.013.. Test accuracy: 0.998
# Epoch 3/10.. Train loss: 0.048.. Test loss: 0.020.. Test accuracy: 0.994
# Epoch 3/10.. Train loss: 0.056.. Test loss: 0.008.. Test accuracy: 0.999
# Epoch 3/10.. Train loss: 0.041.. Test loss: 0.020.. Test accuracy: 0.996
# Epoch 3/10.. Train loss: 0.057.. Test loss: 0.013.. Test accuracy: 0.995
# Epoch 3/10.. Train loss: 0.034.. Test loss: 0.013.. Test accuracy: 0.998
# Epoch 3/10.. Train loss: 0.073.. Test loss: 0.023.. Test accuracy: 0.992
# Epoch 3/10.. Train loss: 0.065.. Test loss: 0.011.. Test accuracy: 0.999
# Epoch 3/10.. Train loss: 0.071.. Test loss: 0.011.. Test accuracy: 0.998
# Epoch 3/10.. Train loss: 0.052.. Test loss: 0.008.. Test accuracy: 0.999
# Epoch 3/10.. Train loss: 0.035.. Test loss: 0.012.. Test accuracy: 0.996
# Epoch 3/10.. Train loss: 0.079.. Test loss: 0.019.. Test accuracy: 0.993
# Epoch 3/10.. Train loss: 0.059.. Test loss: 0.036.. Test accuracy: 0.987
# Epoch 3/10.. Train loss: 0.080.. Test loss: 0.025.. Test accuracy: 0.994
# Epoch 3/10.. Train loss: 0.057.. Test loss: 0.007.. Test accuracy: 0.999
# Epoch 3/10.. Train loss: 0.026.. Test loss: 0.007.. Test accuracy: 0.999
# Epoch 3/10.. Train loss: 0.045.. Test loss: 0.010.. Test accuracy: 0.998
# Epoch 3/10.. Train loss: 0.044.. Test loss: 0.014.. Test accuracy: 0.998
# Epoch 3/10.. Train loss: 0.069.. Test loss: 0.019.. Test accuracy: 0.995
# Epoch 3/10.. Train loss: 0.147.. Test loss: 0.013.. Test accuracy: 0.997
# Epoch 3/10.. Train loss: 0.053.. Test loss: 0.011.. Test accuracy: 0.999
# Epoch 3/10.. Train loss: 0.135.. Test loss: 0.064.. Test accuracy: 0.972
# Epoch 3/10.. Train loss: 0.066.. Test loss: 0.018.. Test accuracy: 0.994
# Epoch 3/10.. Train loss: 0.075.. Test loss: 0.010.. Test accuracy: 0.998
# Epoch 3/10.. Train loss: 0.089.. Test loss: 0.017.. Test accuracy: 0.994
# Epoch 4/10.. Train loss: 0.052.. Test loss: 0.027.. Test accuracy: 0.990
# Epoch 4/10.. Train loss: 0.067.. Test loss: 0.012.. Test accuracy: 0.996
# Epoch 4/10.. Train loss: 0.030.. Test loss: 0.009.. Test accuracy: 0.998
# Epoch 4/10.. Train loss: 0.071.. Test loss: 0.013.. Test accuracy: 0.998
# Epoch 4/10.. Train loss: 0.067.. Test loss: 0.007.. Test accuracy: 0.998
# Epoch 4/10.. Train loss: 0.055.. Test loss: 0.012.. Test accuracy: 0.997
# Epoch 4/10.. Train loss: 0.029.. Test loss: 0.009.. Test accuracy: 0.997
# Epoch 4/10.. Train loss: 0.047.. Test loss: 0.008.. Test accuracy: 0.997
# Epoch 4/10.. Train loss: 0.047.. Test loss: 0.015.. Test accuracy: 0.995
# Epoch 4/10.. Train loss: 0.035.. Test loss: 0.003.. Test accuracy: 0.999
# Epoch 4/10.. Train loss: 0.020.. Test loss: 0.008.. Test accuracy: 0.997
# Epoch 4/10.. Train loss: 0.016.. Test loss: 0.003.. Test accuracy: 0.999
# Epoch 4/10.. Train loss: 0.041.. Test loss: 0.006.. Test accuracy: 0.998
# Epoch 4/10.. Train loss: 0.024.. Test loss: 0.007.. Test accuracy: 0.997
# Epoch 4/10.. Train loss: 0.015.. Test loss: 0.005.. Test accuracy: 0.998
# Epoch 4/10.. Train loss: 0.043.. Test loss: 0.005.. Test accuracy: 1.000
# Epoch 4/10.. Train loss: 0.035.. Test loss: 0.008.. Test accuracy: 0.998
# Epoch 4/10.. Train loss: 0.022.. Test loss: 0.007.. Test accuracy: 0.999
# Epoch 4/10.. Train loss: 0.054.. Test loss: 0.009.. Test accuracy: 0.998
# Epoch 4/10.. Train loss: 0.057.. Test loss: 0.004.. Test accuracy: 0.998
# Epoch 4/10.. Train loss: 0.048.. Test loss: 0.005.. Test accuracy: 0.999
# Epoch 4/10.. Train loss: 0.030.. Test loss: 0.009.. Test accuracy: 0.997
# Epoch 4/10.. Train loss: 0.051.. Test loss: 0.005.. Test accuracy: 0.999
# Epoch 4/10.. Train loss: 0.043.. Test loss: 0.003.. Test accuracy: 0.999
# Epoch 4/10.. Train loss: 0.032.. Test loss: 0.007.. Test accuracy: 0.999
# Epoch 5/10.. Train loss: 0.033.. Test loss: 0.006.. Test accuracy: 0.998
# Epoch 5/10.. Train loss: 0.051.. Test loss: 0.013.. Test accuracy: 0.997
# Epoch 5/10.. Train loss: 0.057.. Test loss: 0.021.. Test accuracy: 0.990
# Epoch 5/10.. Train loss: 0.064.. Test loss: 0.011.. Test accuracy: 0.997
# Epoch 5/10.. Train loss: 0.081.. Test loss: 0.013.. Test accuracy: 0.996
# Epoch 5/10.. Train loss: 0.047.. Test loss: 0.026.. Test accuracy: 0.993
# Epoch 5/10.. Train loss: 0.056.. Test loss: 0.006.. Test accuracy: 0.999
# Epoch 5/10.. Train loss: 0.026.. Test loss: 0.030.. Test accuracy: 0.989
# Epoch 5/10.. Train loss: 0.068.. Test loss: 0.008.. Test accuracy: 0.997
# Epoch 5/10.. Train loss: 0.042.. Test loss: 0.007.. Test accuracy: 0.997
# Epoch 5/10.. Train loss: 0.026.. Test loss: 0.004.. Test accuracy: 0.999
# Epoch 5/10.. Train loss: 0.021.. Test loss: 0.006.. Test accuracy: 0.998
# Epoch 5/10.. Train loss: 0.047.. Test loss: 0.007.. Test accuracy: 0.998
# Epoch 5/10.. Train loss: 0.033.. Test loss: 0.006.. Test accuracy: 0.999
# Epoch 5/10.. Train loss: 0.029.. Test loss: 0.006.. Test accuracy: 0.999
# Epoch 5/10.. Train loss: 0.057.. Test loss: 0.011.. Test accuracy: 0.996
# Epoch 5/10.. Train loss: 0.034.. Test loss: 0.004.. Test accuracy: 0.999
# Epoch 5/10.. Train loss: 0.047.. Test loss: 0.018.. Test accuracy: 0.996
# Epoch 5/10.. Train loss: 0.032.. Test loss: 0.005.. Test accuracy: 0.999
# Epoch 5/10.. Train loss: 0.028.. Test loss: 0.008.. Test accuracy: 0.998
# Epoch 5/10.. Train loss: 0.036.. Test loss: 0.006.. Test accuracy: 0.998
# Epoch 5/10.. Train loss: 0.027.. Test loss: 0.010.. Test accuracy: 0.997
# Epoch 5/10.. Train loss: 0.029.. Test loss: 0.004.. Test accuracy: 0.999
# Epoch 5/10.. Train loss: 0.039.. Test loss: 0.005.. Test accuracy: 0.998
# Epoch 5/10.. Train loss: 0.017.. Test loss: 0.012.. Test accuracy: 0.996
# Epoch 6/10.. Train loss: 0.029.. Test loss: 0.006.. Test accuracy: 0.998
# Epoch 6/10.. Train loss: 0.025.. Test loss: 0.012.. Test accuracy: 0.997
# Epoch 6/10.. Train loss: 0.048.. Test loss: 0.003.. Test accuracy: 1.000
# Epoch 6/10.. Train loss: 0.020.. Test loss: 0.003.. Test accuracy: 1.000
# Epoch 6/10.. Train loss: 0.033.. Test loss: 0.001.. Test accuracy: 1.000
# Epoch 6/10.. Train loss: 0.025.. Test loss: 0.001.. Test accuracy: 1.000
# Epoch 6/10.. Train loss: 0.056.. Test loss: 0.013.. Test accuracy: 0.996
# Epoch 6/10.. Train loss: 0.031.. Test loss: 0.002.. Test accuracy: 1.000
# Epoch 6/10.. Train loss: 0.037.. Test loss: 0.002.. Test accuracy: 1.000
# Epoch 6/10.. Train loss: 0.044.. Test loss: 0.011.. Test accuracy: 0.997
# Epoch 6/10.. Train loss: 0.047.. Test loss: 0.004.. Test accuracy: 1.000
# Epoch 6/10.. Train loss: 0.047.. Test loss: 0.002.. Test accuracy: 1.000
# Epoch 6/10.. Train loss: 0.041.. Test loss: 0.003.. Test accuracy: 1.000
# Epoch 6/10.. Train loss: 0.027.. Test loss: 0.001.. Test accuracy: 1.000
# Epoch 6/10.. Train loss: 0.017.. Test loss: 0.001.. Test accuracy: 1.000
# Epoch 6/10.. Train loss: 0.021.. Test loss: 0.001.. Test accuracy: 1.000
# Epoch 6/10.. Train loss: 0.055.. Test loss: 0.003.. Test accuracy: 0.999
# Epoch 6/10.. Train loss: 0.032.. Test loss: 0.001.. Test accuracy: 1.000
# Epoch 6/10.. Train loss: 0.030.. Test loss: 0.002.. Test accuracy: 1.000
# Epoch 6/10.. Train loss: 0.024.. Test loss: 0.003.. Test accuracy: 0.999
# Epoch 6/10.. Train loss: 0.015.. Test loss: 0.002.. Test accuracy: 1.000
# Epoch 6/10.. Train loss: 0.025.. Test loss: 0.003.. Test accuracy: 0.999
# Epoch 6/10.. Train loss: 0.023.. Test loss: 0.002.. Test accuracy: 0.999
# Epoch 6/10.. Train loss: 0.041.. Test loss: 0.003.. Test accuracy: 0.999
# Epoch 6/10.. Train loss: 0.034.. Test loss: 0.003.. Test accuracy: 1.000
# Epoch 7/10.. Train loss: 0.030.. Test loss: 0.002.. Test accuracy: 1.000
# Epoch 7/10.. Train loss: 0.046.. Test loss: 0.002.. Test accuracy: 1.000
# Epoch 7/10.. Train loss: 0.037.. Test loss: 0.002.. Test accuracy: 1.000
# Epoch 7/10.. Train loss: 0.018.. Test loss: 0.003.. Test accuracy: 1.000
# Epoch 7/10.. Train loss: 0.037.. Test loss: 0.011.. Test accuracy: 0.997
# Epoch 7/10.. Train loss: 0.019.. Test loss: 0.004.. Test accuracy: 0.999
# Epoch 7/10.. Train loss: 0.030.. Test loss: 0.002.. Test accuracy: 1.000
# Epoch 7/10.. Train loss: 0.035.. Test loss: 0.004.. Test accuracy: 0.999
# Epoch 7/10.. Train loss: 0.072.. Test loss: 0.006.. Test accuracy: 0.998
# Epoch 7/10.. Train loss: 0.108.. Test loss: 0.048.. Test accuracy: 0.977
# Epoch 7/10.. Train loss: 0.126.. Test loss: 0.057.. Test accuracy: 0.981
# Epoch 7/10.. Train loss: 0.271.. Test loss: 0.031.. Test accuracy: 0.986
# Epoch 7/10.. Train loss: 0.094.. Test loss: 0.003.. Test accuracy: 0.999
# Epoch 7/10.. Train loss: 0.106.. Test loss: 0.006.. Test accuracy: 0.997
# Epoch 7/10.. Train loss: 0.107.. Test loss: 0.098.. Test accuracy: 0.971
# Epoch 7/10.. Train loss: 0.163.. Test loss: 0.027.. Test accuracy: 0.994
# Epoch 7/10.. Train loss: 0.177.. Test loss: 0.012.. Test accuracy: 0.997
# Epoch 7/10.. Train loss: 0.049.. Test loss: 0.018.. Test accuracy: 0.994
# Epoch 7/10.. Train loss: 0.052.. Test loss: 0.006.. Test accuracy: 0.998
# Epoch 7/10.. Train loss: 0.056.. Test loss: 0.018.. Test accuracy: 0.994
# Epoch 7/10.. Train loss: 0.058.. Test loss: 0.018.. Test accuracy: 0.995
# Epoch 7/10.. Train loss: 0.053.. Test loss: 0.007.. Test accuracy: 0.998
# Epoch 7/10.. Train loss: 0.031.. Test loss: 0.006.. Test accuracy: 0.999
# Epoch 7/10.. Train loss: 0.020.. Test loss: 0.007.. Test accuracy: 0.999
# Epoch 7/10.. Train loss: 0.019.. Test loss: 0.007.. Test accuracy: 0.998
# Epoch 8/10.. Train loss: 0.015.. Test loss: 0.006.. Test accuracy: 0.999
# Epoch 8/10.. Train loss: 0.033.. Test loss: 0.002.. Test accuracy: 1.000
# Epoch 8/10.. Train loss: 0.019.. Test loss: 0.007.. Test accuracy: 0.998
# Epoch 8/10.. Train loss: 0.033.. Test loss: 0.002.. Test accuracy: 1.000
# Epoch 8/10.. Train loss: 0.016.. Test loss: 0.002.. Test accuracy: 1.000
# Epoch 8/10.. Train loss: 0.028.. Test loss: 0.002.. Test accuracy: 1.000
# Epoch 8/10.. Train loss: 0.024.. Test loss: 0.002.. Test accuracy: 1.000
# Epoch 8/10.. Train loss: 0.010.. Test loss: 0.002.. Test accuracy: 1.000
# Epoch 8/10.. Train loss: 0.020.. Test loss: 0.002.. Test accuracy: 1.000
# Epoch 8/10.. Train loss: 0.022.. Test loss: 0.002.. Test accuracy: 1.000
# Epoch 8/10.. Train loss: 0.044.. Test loss: 0.003.. Test accuracy: 0.999
# Epoch 8/10.. Train loss: 0.019.. Test loss: 0.004.. Test accuracy: 1.000
# Epoch 8/10.. Train loss: 0.016.. Test loss: 0.003.. Test accuracy: 0.999
# Epoch 8/10.. Train loss: 0.025.. Test loss: 0.003.. Test accuracy: 1.000
# Epoch 8/10.. Train loss: 0.015.. Test loss: 0.003.. Test accuracy: 1.000
# Epoch 8/10.. Train loss: 0.009.. Test loss: 0.001.. Test accuracy: 1.000
# Epoch 8/10.. Train loss: 0.013.. Test loss: 0.001.. Test accuracy: 1.000
# Epoch 8/10.. Train loss: 0.019.. Test loss: 0.002.. Test accuracy: 1.000
# Epoch 8/10.. Train loss: 0.022.. Test loss: 0.005.. Test accuracy: 1.000
# Epoch 8/10.. Train loss: 0.034.. Test loss: 0.002.. Test accuracy: 1.000
# Epoch 8/10.. Train loss: 0.031.. Test loss: 0.008.. Test accuracy: 0.998
# Epoch 8/10.. Train loss: 0.067.. Test loss: 0.007.. Test accuracy: 0.997
# Epoch 8/10.. Train loss: 0.035.. Test loss: 0.007.. Test accuracy: 0.999
# Epoch 8/10.. Train loss: 0.063.. Test loss: 0.006.. Test accuracy: 0.998
# Epoch 8/10.. Train loss: 0.058.. Test loss: 0.004.. Test accuracy: 0.999
# Epoch 9/10.. Train loss: 0.062.. Test loss: 0.014.. Test accuracy: 0.994
# Epoch 9/10.. Train loss: 0.066.. Test loss: 0.014.. Test accuracy: 0.996
# Epoch 9/10.. Train loss: 0.056.. Test loss: 0.009.. Test accuracy: 0.998
# Epoch 9/10.. Train loss: 0.048.. Test loss: 0.005.. Test accuracy: 0.998
# Epoch 9/10.. Train loss: 0.046.. Test loss: 0.007.. Test accuracy: 0.997
# Epoch 9/10.. Train loss: 0.070.. Test loss: 0.007.. Test accuracy: 0.997
# Epoch 9/10.. Train loss: 0.059.. Test loss: 0.005.. Test accuracy: 0.999
# Epoch 9/10.. Train loss: 0.048.. Test loss: 0.006.. Test accuracy: 0.999
# Epoch 9/10.. Train loss: 0.036.. Test loss: 0.003.. Test accuracy: 0.999
# Epoch 9/10.. Train loss: 0.026.. Test loss: 0.003.. Test accuracy: 0.999
# Epoch 9/10.. Train loss: 0.023.. Test loss: 0.002.. Test accuracy: 1.000
# Epoch 9/10.. Train loss: 0.027.. Test loss: 0.002.. Test accuracy: 0.999
# Epoch 9/10.. Train loss: 0.032.. Test loss: 0.002.. Test accuracy: 1.000
# Epoch 9/10.. Train loss: 0.039.. Test loss: 0.002.. Test accuracy: 1.000
# Epoch 9/10.. Train loss: 0.028.. Test loss: 0.007.. Test accuracy: 0.998
# Epoch 9/10.. Train loss: 0.066.. Test loss: 0.007.. Test accuracy: 0.998
# Epoch 9/10.. Train loss: 0.019.. Test loss: 0.005.. Test accuracy: 0.999
# Epoch 9/10.. Train loss: 0.036.. Test loss: 0.002.. Test accuracy: 1.000
# Epoch 9/10.. Train loss: 0.033.. Test loss: 0.002.. Test accuracy: 1.000
# Epoch 9/10.. Train loss: 0.035.. Test loss: 0.002.. Test accuracy: 1.000
# Epoch 9/10.. Train loss: 0.023.. Test loss: 0.004.. Test accuracy: 0.999
# Epoch 9/10.. Train loss: 0.028.. Test loss: 0.002.. Test accuracy: 0.999
# Epoch 9/10.. Train loss: 0.039.. Test loss: 0.002.. Test accuracy: 1.000
# Epoch 9/10.. Train loss: 0.042.. Test loss: 0.004.. Test accuracy: 0.999
# Epoch 9/10.. Train loss: 0.025.. Test loss: 0.005.. Test accuracy: 0.998
# Epoch 10/10.. Train loss: 0.015.. Test loss: 0.001.. Test accuracy: 1.000
# Epoch 10/10.. Train loss: 0.009.. Test loss: 0.002.. Test accuracy: 1.000
# Epoch 10/10.. Train loss: 0.015.. Test loss: 0.001.. Test accuracy: 1.000
# Epoch 10/10.. Train loss: 0.032.. Test loss: 0.002.. Test accuracy: 1.000
# Epoch 10/10.. Train loss: 0.010.. Test loss: 0.002.. Test accuracy: 1.000
# Epoch 10/10.. Train loss: 0.023.. Test loss: 0.004.. Test accuracy: 0.999
# Epoch 10/10.. Train loss: 0.028.. Test loss: 0.003.. Test accuracy: 0.999
# Epoch 10/10.. Train loss: 0.026.. Test loss: 0.003.. Test accuracy: 0.999
# Epoch 10/10.. Train loss: 0.021.. Test loss: 0.001.. Test accuracy: 1.000
# Epoch 10/10.. Train loss: 0.032.. Test loss: 0.001.. Test accuracy: 1.000
# Epoch 10/10.. Train loss: 0.041.. Test loss: 0.001.. Test accuracy: 1.000
# Epoch 10/10.. Train loss: 0.033.. Test loss: 0.001.. Test accuracy: 1.000
# Epoch 10/10.. Train loss: 0.028.. Test loss: 0.004.. Test accuracy: 0.999
# Epoch 10/10.. Train loss: 0.035.. Test loss: 0.008.. Test accuracy: 0.998
# Epoch 10/10.. Train loss: 0.043.. Test loss: 0.003.. Test accuracy: 1.000
# Epoch 10/10.. Train loss: 0.079.. Test loss: 0.007.. Test accuracy: 0.998
# Epoch 10/10.. Train loss: 0.086.. Test loss: 0.006.. Test accuracy: 0.999
# Epoch 10/10.. Train loss: 0.040.. Test loss: 0.002.. Test accuracy: 1.000
# Epoch 10/10.. Train loss: 0.015.. Test loss: 0.004.. Test accuracy: 0.999
# Epoch 10/10.. Train loss: 0.069.. Test loss: 0.005.. Test accuracy: 0.999
# Epoch 10/10.. Train loss: 0.036.. Test loss: 0.004.. Test accuracy: 1.000
# Epoch 10/10.. Train loss: 0.056.. Test loss: 0.001.. Test accuracy: 1.000
# Epoch 10/10.. Train loss: 0.047.. Test loss: 0.006.. Test accuracy: 0.998
# Epoch 10/10.. Train loss: 0.035.. Test loss: 0.003.. Test accuracy: 0.999
# Epoch 10/10.. Train loss: 0.024.. Test loss: 0.004.. Test accuracy: 1.000

# %%
print("Start time: {}".format(t1))
print("Finishing time: {}".format(t2))

plt.plot(train_losses, label='Training loss')
plt.plot(test_losses, label='Validation loss')
plt.legend(frameon=False)
plt.show()
accuracy = 0
with torch.no_grad():
    for inputs, labels in testloader:
        inputs, labels = inputs.to(device), labels.to(device)
        logps = model.forward(inputs)
        batch_loss = criterion(logps, labels)
        test_loss += batch_loss.item()

        ps = torch.exp(logps)
        top_p, top_class = ps.topk(1, dim=1)
        equals = top_class == labels.view(*top_class.shape)
        accuracy += torch.mean(equals.type(torch.FloatTensor)).item()

print(f"Test accuracy: {accuracy/len(testloader):.3f}")
# Out:
# Start time: 2019-10-06 18:30:56.827657
# Finishing time: 2019-10-06 19:14:31.734671
# Test accuracy: 0.953
