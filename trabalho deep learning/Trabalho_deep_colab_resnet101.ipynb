# %%
#!unzip ./drive/'My Drive'/dataset/leapGestRecog.zip

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
import torchvision
import numpy as np
from torchvision import datasets, transforms, models
from torch.utils.data.sampler import SubsetRandomSampler
from datetime import datetime

# %%
# Parameters
BATCH_SIZE = 64
RESIZE = 256
EPOCHS = 10
MODEL = models.resnet101
OUR_TOPOLOGY = nn.Sequential(nn.Linear(2048, 512),
                                 nn.ReLU(),
                                 nn.Dropout(0.2),
                                 nn.Linear(512, 10),
                                 nn.LogSoftmax(dim=1))
OPTIMIZER = optim.Adam
OPTIMIZER_PARAMETERS = {"lr": 0.003}

# %%
transform = transforms.Compose([
    transforms.Resize(RESIZE),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

alldataset = torchvision.datasets.ImageFolder(root='./leapGestRecog/00', transform=transform)

for i in range(1, 10):
    folder = torchvision.datasets.ImageFolder(root='./leapGestRecog/0{}'.format(i), transform=transform)
    alldataset = torch.utils.data.ConcatDataset([alldataset, folder])


def split_train_test(indices, seed=42):
    np.random.seed(seed)
    np.random.shuffle(indices)
    train_idx, test_idx = indices[split:], indices[:split]
    train_sampler = SubsetRandomSampler(train_idx)
    test_sampler = SubsetRandomSampler(test_idx)
    trainloader = torch.utils.data.DataLoader(
        alldataset, batch_size=BATCH_SIZE, sampler=train_sampler,
        num_workers=12
    )
    testloader = torch.utils.data.DataLoader(
        alldataset, batch_size=BATCH_SIZE, sampler=test_sampler,
    )
    return train_idx, trainloader, test_idx, testloader

num_train = len(alldataset)
indices = list(range(num_train))
split = int(np.floor(0.1 * num_train))

train_idx, trainloader, test_idx, testloader = split_train_test(indices)
_, trainloader, _, validloader = split_train_test(train_idx)

classes = ('01_palm', '02_l', '03_fist', '04_fist_moved',
           '05_thumb', '06_index', '07_ok', '08_palm_moved', '09_c', '10_down')

# %%
print(len(trainloader), len(validloader), len(testloader))
# Out:
# 250 32 32

# %%
import matplotlib.pyplot as plt
import numpy as np

# functions to show an image


def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
dataiter = iter(trainloader)
images, labels = dataiter.next()

# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(BATCH_SIZE)))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 10_down  09_c 07_ok 04_fist_moved 05_thumb 05_thumb 05_thumb 03_fist 03_fist  02_l 07_ok 03_fist 06_index 08_palm_moved 05_thumb 08_palm_moved 08_palm_moved 07_ok 05_thumb 03_fist  02_l  09_c 04_fist_moved 10_down 10_down  02_l 01_palm 10_down 03_fist 01_palm  09_c  09_c  09_c 07_ok  02_l  02_l 08_palm_moved 10_down 01_palm 03_fist 06_index 10_down 07_ok 08_palm_moved 08_palm_moved 05_thumb 03_fist 01_palm 06_index 07_ok 07_ok 10_down 07_ok 06_index  02_l 03_fist 03_fist 05_thumb 01_palm 08_palm_moved  09_c 04_fist_moved 07_ok 07_ok

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
model = MODEL(pretrained=True)
model
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (8): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (9): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (10): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (11): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (12): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (13): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (14): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (15): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (16): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (17): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (18): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (19): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (20): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (21): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (22): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %%
# Freeze parameters so we don't backprop through them
for param in model.parameters():
    param.requires_grad = False
    
model.fc = OUR_TOPOLOGY
criterion = nn.NLLLoss()
optimizer = OPTIMIZER(model.parameters(), **OPTIMIZER_PARAMETERS)
model.to(device)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (8): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (9): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (10): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (11): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (12): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (13): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (14): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (15): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (16): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (17): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (18): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (19): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (20): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (21): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (22): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=512, out_features=10, bias=True)
#     (4): LogSoftmax()
#   )
# )

# %%
epochs = EPOCHS
steps = 0
running_loss = 0
print_every = 10
train_losses, test_losses = [], []

t1 = datetime.now()
for epoch in range(epochs):
    _, trainloader, _, validloader = split_train_test(train_idx)
    for inputs, labels in trainloader:
        steps += 1
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        logps = model.forward(inputs)
        loss = criterion(logps, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        
        if steps % print_every == 0:
            test_loss = 0
            accuracy = 0
            model.eval()
            with torch.no_grad():
                for inputs, labels in validloader:
                    inputs, labels = inputs.to(device), labels.to(device)
                    logps = model.forward(inputs)
                    batch_loss = criterion(logps, labels)
                    test_loss += batch_loss.item()
                    
                    ps = torch.exp(logps)
                    top_p, top_class = ps.topk(1, dim=1)
                    equals = top_class == labels.view(*top_class.shape)
                    accuracy += torch.mean(equals.type(torch.FloatTensor)).item()

            train_losses.append(running_loss/len(trainloader))
            test_losses.append(test_loss/len(validloader))                    
            print(f"Epoch {epoch+1}/{epochs}.. "
                  f"Train loss: {running_loss/print_every:.3f}.. "
                  f"Test loss: {test_loss/len(validloader):.3f}.. "
                  f"Test accuracy: {accuracy/len(validloader):.3f}")
            running_loss = 0
            model.train()
t2 = datetime.now()
# Out:
# Epoch 1/10.. Train loss: 2.747.. Test loss: 2.051.. Test accuracy: 0.399
# Epoch 1/10.. Train loss: 1.462.. Test loss: 1.315.. Test accuracy: 0.526
# Epoch 1/10.. Train loss: 0.760.. Test loss: 0.964.. Test accuracy: 0.663
# Epoch 1/10.. Train loss: 0.601.. Test loss: 0.819.. Test accuracy: 0.737
# Epoch 1/10.. Train loss: 0.443.. Test loss: 0.396.. Test accuracy: 0.887
# Epoch 1/10.. Train loss: 0.365.. Test loss: 0.240.. Test accuracy: 0.953
# Epoch 1/10.. Train loss: 0.265.. Test loss: 0.201.. Test accuracy: 0.944
# Epoch 1/10.. Train loss: 0.307.. Test loss: 0.173.. Test accuracy: 0.942
# Epoch 1/10.. Train loss: 0.211.. Test loss: 0.113.. Test accuracy: 0.976
# Epoch 1/10.. Train loss: 0.138.. Test loss: 0.126.. Test accuracy: 0.966
# Epoch 1/10.. Train loss: 0.155.. Test loss: 0.077.. Test accuracy: 0.984
# Epoch 1/10.. Train loss: 0.164.. Test loss: 0.096.. Test accuracy: 0.976
# Epoch 1/10.. Train loss: 0.114.. Test loss: 0.072.. Test accuracy: 0.987
# Epoch 1/10.. Train loss: 0.143.. Test loss: 0.057.. Test accuracy: 0.988
# Epoch 1/10.. Train loss: 0.104.. Test loss: 0.060.. Test accuracy: 0.985
# Epoch 1/10.. Train loss: 0.118.. Test loss: 0.096.. Test accuracy: 0.969
# Epoch 1/10.. Train loss: 0.117.. Test loss: 0.055.. Test accuracy: 0.987
# Epoch 1/10.. Train loss: 0.100.. Test loss: 0.092.. Test accuracy: 0.977
# Epoch 1/10.. Train loss: 0.092.. Test loss: 0.050.. Test accuracy: 0.990
# Epoch 1/10.. Train loss: 0.083.. Test loss: 0.074.. Test accuracy: 0.981
# Epoch 1/10.. Train loss: 0.086.. Test loss: 0.045.. Test accuracy: 0.986
# Epoch 1/10.. Train loss: 0.070.. Test loss: 0.059.. Test accuracy: 0.982
# Epoch 1/10.. Train loss: 0.081.. Test loss: 0.030.. Test accuracy: 0.991
# Epoch 1/10.. Train loss: 0.058.. Test loss: 0.052.. Test accuracy: 0.986
# Epoch 1/10.. Train loss: 0.063.. Test loss: 0.040.. Test accuracy: 0.990
# Epoch 2/10.. Train loss: 0.075.. Test loss: 0.033.. Test accuracy: 0.992
# Epoch 2/10.. Train loss: 0.106.. Test loss: 0.069.. Test accuracy: 0.977
# Epoch 2/10.. Train loss: 0.089.. Test loss: 0.046.. Test accuracy: 0.986
# Epoch 2/10.. Train loss: 0.052.. Test loss: 0.028.. Test accuracy: 0.992
# Epoch 2/10.. Train loss: 0.053.. Test loss: 0.027.. Test accuracy: 0.992
# Epoch 2/10.. Train loss: 0.040.. Test loss: 0.023.. Test accuracy: 0.994
# Epoch 2/10.. Train loss: 0.062.. Test loss: 0.046.. Test accuracy: 0.987
# Epoch 2/10.. Train loss: 0.078.. Test loss: 0.048.. Test accuracy: 0.985
# Epoch 2/10.. Train loss: 0.056.. Test loss: 0.026.. Test accuracy: 0.995
# Epoch 2/10.. Train loss: 0.100.. Test loss: 0.025.. Test accuracy: 0.992
# Epoch 2/10.. Train loss: 0.087.. Test loss: 0.029.. Test accuracy: 0.993
# Epoch 2/10.. Train loss: 0.069.. Test loss: 0.021.. Test accuracy: 0.993
# Epoch 2/10.. Train loss: 0.093.. Test loss: 0.033.. Test accuracy: 0.987
# Epoch 2/10.. Train loss: 0.087.. Test loss: 0.058.. Test accuracy: 0.984
# Epoch 2/10.. Train loss: 0.052.. Test loss: 0.025.. Test accuracy: 0.991
# Epoch 2/10.. Train loss: 0.048.. Test loss: 0.027.. Test accuracy: 0.992
# Epoch 2/10.. Train loss: 0.047.. Test loss: 0.024.. Test accuracy: 0.991
# Epoch 2/10.. Train loss: 0.053.. Test loss: 0.026.. Test accuracy: 0.992
# Epoch 2/10.. Train loss: 0.032.. Test loss: 0.020.. Test accuracy: 0.993
# Epoch 2/10.. Train loss: 0.040.. Test loss: 0.023.. Test accuracy: 0.992
# Epoch 2/10.. Train loss: 0.032.. Test loss: 0.017.. Test accuracy: 0.995
# Epoch 2/10.. Train loss: 0.029.. Test loss: 0.018.. Test accuracy: 0.996
# Epoch 2/10.. Train loss: 0.022.. Test loss: 0.019.. Test accuracy: 0.994
# Epoch 2/10.. Train loss: 0.059.. Test loss: 0.037.. Test accuracy: 0.989
# Epoch 2/10.. Train loss: 0.069.. Test loss: 0.035.. Test accuracy: 0.989
# Epoch 3/10.. Train loss: 0.047.. Test loss: 0.045.. Test accuracy: 0.983
# Epoch 3/10.. Train loss: 0.049.. Test loss: 0.026.. Test accuracy: 0.993
# Epoch 3/10.. Train loss: 0.032.. Test loss: 0.013.. Test accuracy: 0.997
# Epoch 3/10.. Train loss: 0.028.. Test loss: 0.009.. Test accuracy: 0.997
# Epoch 3/10.. Train loss: 0.030.. Test loss: 0.018.. Test accuracy: 0.994
# Epoch 3/10.. Train loss: 0.035.. Test loss: 0.016.. Test accuracy: 0.994
# Epoch 3/10.. Train loss: 0.064.. Test loss: 0.012.. Test accuracy: 0.998
# Epoch 3/10.. Train loss: 0.055.. Test loss: 0.071.. Test accuracy: 0.976
# Epoch 3/10.. Train loss: 0.102.. Test loss: 0.017.. Test accuracy: 0.995
# Epoch 3/10.. Train loss: 0.085.. Test loss: 0.102.. Test accuracy: 0.966
# Epoch 3/10.. Train loss: 0.131.. Test loss: 0.021.. Test accuracy: 0.994
# Epoch 3/10.. Train loss: 0.091.. Test loss: 0.066.. Test accuracy: 0.978
# Epoch 3/10.. Train loss: 0.138.. Test loss: 0.025.. Test accuracy: 0.991
# Epoch 3/10.. Train loss: 0.099.. Test loss: 0.026.. Test accuracy: 0.993
# Epoch 3/10.. Train loss: 0.066.. Test loss: 0.046.. Test accuracy: 0.986
# Epoch 3/10.. Train loss: 0.055.. Test loss: 0.043.. Test accuracy: 0.989
# Epoch 3/10.. Train loss: 0.056.. Test loss: 0.018.. Test accuracy: 0.992
# Epoch 3/10.. Train loss: 0.068.. Test loss: 0.080.. Test accuracy: 0.969
# Epoch 3/10.. Train loss: 0.090.. Test loss: 0.027.. Test accuracy: 0.992
# Epoch 3/10.. Train loss: 0.079.. Test loss: 0.030.. Test accuracy: 0.990
# Epoch 3/10.. Train loss: 0.047.. Test loss: 0.019.. Test accuracy: 0.993
# Epoch 3/10.. Train loss: 0.043.. Test loss: 0.016.. Test accuracy: 0.994
# Epoch 3/10.. Train loss: 0.045.. Test loss: 0.016.. Test accuracy: 0.995
# Epoch 3/10.. Train loss: 0.026.. Test loss: 0.008.. Test accuracy: 0.998
# Epoch 3/10.. Train loss: 0.043.. Test loss: 0.020.. Test accuracy: 0.995
# Epoch 4/10.. Train loss: 0.058.. Test loss: 0.016.. Test accuracy: 0.995
# Epoch 4/10.. Train loss: 0.029.. Test loss: 0.012.. Test accuracy: 0.997
# Epoch 4/10.. Train loss: 0.054.. Test loss: 0.019.. Test accuracy: 0.995
# Epoch 4/10.. Train loss: 0.018.. Test loss: 0.012.. Test accuracy: 0.998
# Epoch 4/10.. Train loss: 0.040.. Test loss: 0.013.. Test accuracy: 0.997
# Epoch 4/10.. Train loss: 0.028.. Test loss: 0.025.. Test accuracy: 0.992
# Epoch 4/10.. Train loss: 0.056.. Test loss: 0.096.. Test accuracy: 0.965
# Epoch 4/10.. Train loss: 0.055.. Test loss: 0.009.. Test accuracy: 0.998
# Epoch 4/10.. Train loss: 0.066.. Test loss: 0.081.. Test accuracy: 0.973
# Epoch 4/10.. Train loss: 0.073.. Test loss: 0.022.. Test accuracy: 0.993
# Epoch 4/10.. Train loss: 0.054.. Test loss: 0.045.. Test accuracy: 0.987
# Epoch 4/10.. Train loss: 0.093.. Test loss: 0.026.. Test accuracy: 0.992
# Epoch 4/10.. Train loss: 0.032.. Test loss: 0.023.. Test accuracy: 0.992
# Epoch 4/10.. Train loss: 0.032.. Test loss: 0.010.. Test accuracy: 0.997
# Epoch 4/10.. Train loss: 0.044.. Test loss: 0.029.. Test accuracy: 0.992
# Epoch 4/10.. Train loss: 0.049.. Test loss: 0.054.. Test accuracy: 0.983
# Epoch 4/10.. Train loss: 0.066.. Test loss: 0.035.. Test accuracy: 0.991
# Epoch 4/10.. Train loss: 0.042.. Test loss: 0.017.. Test accuracy: 0.995
# Epoch 4/10.. Train loss: 0.023.. Test loss: 0.033.. Test accuracy: 0.992
# Epoch 4/10.. Train loss: 0.008.. Test loss: 0.012.. Test accuracy: 0.996
# Epoch 4/10.. Train loss: 0.009.. Test loss: 0.007.. Test accuracy: 0.999
# Epoch 4/10.. Train loss: 0.023.. Test loss: 0.014.. Test accuracy: 0.995
# Epoch 4/10.. Train loss: 0.038.. Test loss: 0.018.. Test accuracy: 0.995
# Epoch 4/10.. Train loss: 0.045.. Test loss: 0.021.. Test accuracy: 0.996
# Epoch 4/10.. Train loss: 0.024.. Test loss: 0.007.. Test accuracy: 0.998
# Epoch 5/10.. Train loss: 0.019.. Test loss: 0.020.. Test accuracy: 0.995
# Epoch 5/10.. Train loss: 0.029.. Test loss: 0.009.. Test accuracy: 0.997
# Epoch 5/10.. Train loss: 0.022.. Test loss: 0.015.. Test accuracy: 0.995
# Epoch 5/10.. Train loss: 0.022.. Test loss: 0.008.. Test accuracy: 0.997
# Epoch 5/10.. Train loss: 0.031.. Test loss: 0.005.. Test accuracy: 0.999
# Epoch 5/10.. Train loss: 0.018.. Test loss: 0.030.. Test accuracy: 0.992
# Epoch 5/10.. Train loss: 0.029.. Test loss: 0.014.. Test accuracy: 0.995
# Epoch 5/10.. Train loss: 0.033.. Test loss: 0.015.. Test accuracy: 0.993
# Epoch 5/10.. Train loss: 0.021.. Test loss: 0.015.. Test accuracy: 0.993
# Epoch 5/10.. Train loss: 0.019.. Test loss: 0.029.. Test accuracy: 0.992
# Epoch 5/10.. Train loss: 0.012.. Test loss: 0.010.. Test accuracy: 0.995
# Epoch 5/10.. Train loss: 0.028.. Test loss: 0.009.. Test accuracy: 0.997
# Epoch 5/10.. Train loss: 0.016.. Test loss: 0.022.. Test accuracy: 0.994
# Epoch 5/10.. Train loss: 0.018.. Test loss: 0.010.. Test accuracy: 0.997
# Epoch 5/10.. Train loss: 0.027.. Test loss: 0.014.. Test accuracy: 0.995
# Epoch 5/10.. Train loss: 0.053.. Test loss: 0.030.. Test accuracy: 0.992
# Epoch 5/10.. Train loss: 0.067.. Test loss: 0.038.. Test accuracy: 0.988
# Epoch 5/10.. Train loss: 0.118.. Test loss: 0.069.. Test accuracy: 0.973
# Epoch 5/10.. Train loss: 0.141.. Test loss: 0.014.. Test accuracy: 0.996
# Epoch 5/10.. Train loss: 0.076.. Test loss: 0.012.. Test accuracy: 0.997
# Epoch 5/10.. Train loss: 0.051.. Test loss: 0.031.. Test accuracy: 0.991
# Epoch 5/10.. Train loss: 0.053.. Test loss: 0.045.. Test accuracy: 0.986
# Epoch 5/10.. Train loss: 0.042.. Test loss: 0.031.. Test accuracy: 0.990
# Epoch 5/10.. Train loss: 0.013.. Test loss: 0.016.. Test accuracy: 0.995
# Epoch 5/10.. Train loss: 0.038.. Test loss: 0.015.. Test accuracy: 0.996
# Epoch 6/10.. Train loss: 0.032.. Test loss: 0.016.. Test accuracy: 0.994
# Epoch 6/10.. Train loss: 0.039.. Test loss: 0.025.. Test accuracy: 0.993
# Epoch 6/10.. Train loss: 0.035.. Test loss: 0.024.. Test accuracy: 0.994
# Epoch 6/10.. Train loss: 0.033.. Test loss: 0.013.. Test accuracy: 0.995
# Epoch 6/10.. Train loss: 0.036.. Test loss: 0.041.. Test accuracy: 0.988
# Epoch 6/10.. Train loss: 0.032.. Test loss: 0.034.. Test accuracy: 0.988
# Epoch 6/10.. Train loss: 0.042.. Test loss: 0.010.. Test accuracy: 0.996
# Epoch 6/10.. Train loss: 0.021.. Test loss: 0.009.. Test accuracy: 0.999
# Epoch 6/10.. Train loss: 0.031.. Test loss: 0.006.. Test accuracy: 0.999
# Epoch 6/10.. Train loss: 0.025.. Test loss: 0.010.. Test accuracy: 0.997
# Epoch 6/10.. Train loss: 0.014.. Test loss: 0.008.. Test accuracy: 0.998
# Epoch 6/10.. Train loss: 0.026.. Test loss: 0.070.. Test accuracy: 0.990
# Epoch 6/10.. Train loss: 0.026.. Test loss: 0.014.. Test accuracy: 0.997
# Epoch 6/10.. Train loss: 0.077.. Test loss: 0.006.. Test accuracy: 0.998
# Epoch 6/10.. Train loss: 0.057.. Test loss: 0.004.. Test accuracy: 0.999
# Epoch 6/10.. Train loss: 0.093.. Test loss: 0.050.. Test accuracy: 0.989
# Epoch 6/10.. Train loss: 0.047.. Test loss: 0.041.. Test accuracy: 0.987
# Epoch 6/10.. Train loss: 0.052.. Test loss: 0.035.. Test accuracy: 0.987
# Epoch 6/10.. Train loss: 0.062.. Test loss: 0.014.. Test accuracy: 0.996
# Epoch 6/10.. Train loss: 0.098.. Test loss: 0.036.. Test accuracy: 0.984
# Epoch 6/10.. Train loss: 0.152.. Test loss: 0.041.. Test accuracy: 0.987
# Epoch 6/10.. Train loss: 0.134.. Test loss: 0.085.. Test accuracy: 0.988
# Epoch 6/10.. Train loss: 0.076.. Test loss: 0.017.. Test accuracy: 0.995
# Epoch 6/10.. Train loss: 0.036.. Test loss: 0.034.. Test accuracy: 0.989
# Epoch 6/10.. Train loss: 0.064.. Test loss: 0.028.. Test accuracy: 0.993
# Epoch 7/10.. Train loss: 0.036.. Test loss: 0.009.. Test accuracy: 0.997
# Epoch 7/10.. Train loss: 0.025.. Test loss: 0.012.. Test accuracy: 0.996
# Epoch 7/10.. Train loss: 0.040.. Test loss: 0.009.. Test accuracy: 0.997
# Epoch 7/10.. Train loss: 0.017.. Test loss: 0.015.. Test accuracy: 0.995
# Epoch 7/10.. Train loss: 0.051.. Test loss: 0.009.. Test accuracy: 0.998
# Epoch 7/10.. Train loss: 0.062.. Test loss: 0.013.. Test accuracy: 0.997
# Epoch 7/10.. Train loss: 0.039.. Test loss: 0.009.. Test accuracy: 0.998
# Epoch 7/10.. Train loss: 0.017.. Test loss: 0.017.. Test accuracy: 0.996
# Epoch 7/10.. Train loss: 0.030.. Test loss: 0.013.. Test accuracy: 0.996
# Epoch 7/10.. Train loss: 0.032.. Test loss: 0.011.. Test accuracy: 0.996
# Epoch 7/10.. Train loss: 0.019.. Test loss: 0.011.. Test accuracy: 0.996
# Epoch 7/10.. Train loss: 0.035.. Test loss: 0.007.. Test accuracy: 0.997
# Epoch 7/10.. Train loss: 0.041.. Test loss: 0.012.. Test accuracy: 0.997
# Epoch 7/10.. Train loss: 0.051.. Test loss: 0.022.. Test accuracy: 0.991
# Epoch 7/10.. Train loss: 0.031.. Test loss: 0.023.. Test accuracy: 0.996
# Epoch 7/10.. Train loss: 0.031.. Test loss: 0.018.. Test accuracy: 0.995
# Epoch 7/10.. Train loss: 0.058.. Test loss: 0.013.. Test accuracy: 0.996
# Epoch 7/10.. Train loss: 0.028.. Test loss: 0.007.. Test accuracy: 0.997
# Epoch 7/10.. Train loss: 0.022.. Test loss: 0.009.. Test accuracy: 0.997
# Epoch 7/10.. Train loss: 0.020.. Test loss: 0.011.. Test accuracy: 0.996
# Epoch 7/10.. Train loss: 0.023.. Test loss: 0.010.. Test accuracy: 0.997
# Epoch 7/10.. Train loss: 0.039.. Test loss: 0.061.. Test accuracy: 0.992
# Epoch 7/10.. Train loss: 0.030.. Test loss: 0.031.. Test accuracy: 0.991
# Epoch 7/10.. Train loss: 0.042.. Test loss: 0.023.. Test accuracy: 0.993
# Epoch 7/10.. Train loss: 0.029.. Test loss: 0.017.. Test accuracy: 0.994
# Epoch 8/10.. Train loss: 0.043.. Test loss: 0.008.. Test accuracy: 0.998
# Epoch 8/10.. Train loss: 0.028.. Test loss: 0.044.. Test accuracy: 0.991
# Epoch 8/10.. Train loss: 0.033.. Test loss: 0.046.. Test accuracy: 0.988
# Epoch 8/10.. Train loss: 0.044.. Test loss: 0.017.. Test accuracy: 0.993
# Epoch 8/10.. Train loss: 0.028.. Test loss: 0.011.. Test accuracy: 0.996
# Epoch 8/10.. Train loss: 0.039.. Test loss: 0.005.. Test accuracy: 0.999
# Epoch 8/10.. Train loss: 0.029.. Test loss: 0.008.. Test accuracy: 0.996
# Epoch 8/10.. Train loss: 0.016.. Test loss: 0.004.. Test accuracy: 0.999
# Epoch 8/10.. Train loss: 0.018.. Test loss: 0.011.. Test accuracy: 0.997
# Epoch 8/10.. Train loss: 0.040.. Test loss: 0.028.. Test accuracy: 0.991
# Epoch 8/10.. Train loss: 0.079.. Test loss: 0.015.. Test accuracy: 0.996
# Epoch 8/10.. Train loss: 0.097.. Test loss: 0.021.. Test accuracy: 0.994
# Epoch 8/10.. Train loss: 0.058.. Test loss: 0.007.. Test accuracy: 0.998
# Epoch 8/10.. Train loss: 0.055.. Test loss: 0.013.. Test accuracy: 0.994
# Epoch 8/10.. Train loss: 0.035.. Test loss: 0.011.. Test accuracy: 0.997
# Epoch 8/10.. Train loss: 0.034.. Test loss: 0.039.. Test accuracy: 0.987
# Epoch 8/10.. Train loss: 0.034.. Test loss: 0.009.. Test accuracy: 0.997
# Epoch 8/10.. Train loss: 0.053.. Test loss: 0.028.. Test accuracy: 0.992
# Epoch 8/10.. Train loss: 0.074.. Test loss: 0.015.. Test accuracy: 0.995
# Epoch 8/10.. Train loss: 0.066.. Test loss: 0.020.. Test accuracy: 0.993
# Epoch 8/10.. Train loss: 0.049.. Test loss: 0.029.. Test accuracy: 0.990
# Epoch 8/10.. Train loss: 0.045.. Test loss: 0.011.. Test accuracy: 0.996
# Epoch 8/10.. Train loss: 0.024.. Test loss: 0.013.. Test accuracy: 0.995
# Epoch 8/10.. Train loss: 0.029.. Test loss: 0.040.. Test accuracy: 0.992
# Epoch 8/10.. Train loss: 0.013.. Test loss: 0.019.. Test accuracy: 0.994
# Epoch 9/10.. Train loss: 0.010.. Test loss: 0.003.. Test accuracy: 0.999
# Epoch 9/10.. Train loss: 0.013.. Test loss: 0.008.. Test accuracy: 0.996
# Epoch 9/10.. Train loss: 0.015.. Test loss: 0.055.. Test accuracy: 0.989
# Epoch 9/10.. Train loss: 0.036.. Test loss: 0.004.. Test accuracy: 1.000
# Epoch 9/10.. Train loss: 0.030.. Test loss: 0.006.. Test accuracy: 0.998
# Epoch 9/10.. Train loss: 0.035.. Test loss: 0.024.. Test accuracy: 0.990
# Epoch 9/10.. Train loss: 0.055.. Test loss: 0.014.. Test accuracy: 0.996
# Epoch 9/10.. Train loss: 0.047.. Test loss: 0.006.. Test accuracy: 0.998
# Epoch 9/10.. Train loss: 0.058.. Test loss: 0.026.. Test accuracy: 0.993
# Epoch 9/10.. Train loss: 0.042.. Test loss: 0.015.. Test accuracy: 0.995
# Epoch 9/10.. Train loss: 0.055.. Test loss: 0.016.. Test accuracy: 0.996
# Epoch 9/10.. Train loss: 0.018.. Test loss: 0.006.. Test accuracy: 0.999
# Epoch 9/10.. Train loss: 0.068.. Test loss: 0.020.. Test accuracy: 0.994
# Epoch 9/10.. Train loss: 0.037.. Test loss: 0.002.. Test accuracy: 1.000
# Epoch 9/10.. Train loss: 0.042.. Test loss: 0.005.. Test accuracy: 0.999
# Epoch 9/10.. Train loss: 0.077.. Test loss: 0.002.. Test accuracy: 1.000
# Epoch 9/10.. Train loss: 0.088.. Test loss: 0.016.. Test accuracy: 0.995
# Epoch 9/10.. Train loss: 0.061.. Test loss: 0.024.. Test accuracy: 0.993
# Epoch 9/10.. Train loss: 0.043.. Test loss: 0.009.. Test accuracy: 0.996
# Epoch 9/10.. Train loss: 0.051.. Test loss: 0.014.. Test accuracy: 0.995
# Epoch 9/10.. Train loss: 0.055.. Test loss: 0.008.. Test accuracy: 0.999
# Epoch 9/10.. Train loss: 0.043.. Test loss: 0.007.. Test accuracy: 0.998
# Epoch 9/10.. Train loss: 0.058.. Test loss: 0.028.. Test accuracy: 0.990
# Epoch 9/10.. Train loss: 0.060.. Test loss: 0.014.. Test accuracy: 0.995
# Epoch 9/10.. Train loss: 0.048.. Test loss: 0.008.. Test accuracy: 0.998
# Epoch 10/10.. Train loss: 0.031.. Test loss: 0.004.. Test accuracy: 0.999
# Epoch 10/10.. Train loss: 0.037.. Test loss: 0.004.. Test accuracy: 1.000
# Epoch 10/10.. Train loss: 0.038.. Test loss: 0.017.. Test accuracy: 0.996
# Epoch 10/10.. Train loss: 0.045.. Test loss: 0.005.. Test accuracy: 0.999
# Epoch 10/10.. Train loss: 0.035.. Test loss: 0.007.. Test accuracy: 0.996
# Epoch 10/10.. Train loss: 0.030.. Test loss: 0.012.. Test accuracy: 0.997
# Epoch 10/10.. Train loss: 0.029.. Test loss: 0.020.. Test accuracy: 0.996
# Epoch 10/10.. Train loss: 0.030.. Test loss: 0.011.. Test accuracy: 0.996
# Epoch 10/10.. Train loss: 0.045.. Test loss: 0.017.. Test accuracy: 0.995
# Epoch 10/10.. Train loss: 0.046.. Test loss: 0.033.. Test accuracy: 0.990
# Epoch 10/10.. Train loss: 0.055.. Test loss: 0.018.. Test accuracy: 0.995
# Epoch 10/10.. Train loss: 0.074.. Test loss: 0.018.. Test accuracy: 0.995
# Epoch 10/10.. Train loss: 0.047.. Test loss: 0.010.. Test accuracy: 0.996
# Epoch 10/10.. Train loss: 0.044.. Test loss: 0.015.. Test accuracy: 0.994
# Epoch 10/10.. Train loss: 0.040.. Test loss: 0.009.. Test accuracy: 0.997
# Epoch 10/10.. Train loss: 0.065.. Test loss: 0.044.. Test accuracy: 0.991
# Epoch 10/10.. Train loss: 0.044.. Test loss: 0.008.. Test accuracy: 0.997
# Epoch 10/10.. Train loss: 0.058.. Test loss: 0.010.. Test accuracy: 0.998
# Epoch 10/10.. Train loss: 0.024.. Test loss: 0.014.. Test accuracy: 0.997
# Epoch 10/10.. Train loss: 0.022.. Test loss: 0.021.. Test accuracy: 0.995
# Epoch 10/10.. Train loss: 0.044.. Test loss: 0.004.. Test accuracy: 0.999
# Epoch 10/10.. Train loss: 0.041.. Test loss: 0.007.. Test accuracy: 0.997
# Epoch 10/10.. Train loss: 0.020.. Test loss: 0.006.. Test accuracy: 0.997
# Epoch 10/10.. Train loss: 0.021.. Test loss: 0.007.. Test accuracy: 0.998
# Epoch 10/10.. Train loss: 0.029.. Test loss: 0.006.. Test accuracy: 0.998

# %%
print("Start time: {}".format(t1))
print("Finishing time: {}".format(t2))

plt.plot(train_losses, label='Training loss')
plt.plot(test_losses, label='Validation loss')
plt.legend(frameon=False)
plt.show()
accuracy = 0
with torch.no_grad():
    for inputs, labels in testloader:
        inputs, labels = inputs.to(device), labels.to(device)
        logps = model.forward(inputs)
        batch_loss = criterion(logps, labels)
        test_loss += batch_loss.item()

        ps = torch.exp(logps)
        top_p, top_class = ps.topk(1, dim=1)
        equals = top_class == labels.view(*top_class.shape)
        accuracy += torch.mean(equals.type(torch.FloatTensor)).item()

print(f"Test accuracy: {accuracy/len(testloader):.3f}")
# Out:
# Start time: 2019-10-06 21:34:57.558659
# Finishing time: 2019-10-07 00:23:43.405432
# Test accuracy: 0.987
